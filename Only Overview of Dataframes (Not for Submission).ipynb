# %%
import pandas as pd

# %%
df1 = pd.read_csv('csv/borough_entity.csv')
df1.head()
# Out:
#            Borough_Name Converted_Coordinates Borough_Population
# 0  Barking and Dagenham       51.5607, 0.1557            219,992
# 1                Barnet      51.6252, -0.1517            389,101
# 2                Bexley       51.4549, 0.1505            247,835
# 3                 Brent      51.5588, -0.2817            341,221
# 4               Bromley       51.4039, 0.0198            329,578

# %%
df1 = pd.read_csv('csv/cafe_entity.csv')
df1.head()
# Out:
#                         Cafe_Name                     Place_Id  \
# 0                    Take a Break  ChIJP5iSZRul2EcRuLlMBSZy-JY
# 1        Asda Dagenham Superstore  ChIJdwGW-HOl2EcRkRKhL91oI_s
# 2  Becontree Heath Leisure Centre  ChIJfRvpP_yk2EcRMHJ8P6PE448
# 3     Harrow Lodge Leisure Centre  ChIJbz00eCW72EcRv-wkpDkmsGQ
# 4     Eastbrook Cafe & Restuarant  ChIJmSZw6z2l2EcRpS8prTdOqic
#
#                Cafe_Coordinates                          Vicinity  \
# 0  51.55102600000001, 0.1547964          244 Oxlow Lane, Dagenham
# 1         51.5301912, 0.1422174    Merrielands Crescent, Dagenham
# 2         51.5609465, 0.1488995            Althorne Way, Dagenham
# 3          51.5613365, 0.207073       Hornchurch Road, Hornchurch
# 4         51.5508213, 0.1614183  264 Rainham Road South, Dagenham
#
#                                           Cafe_Types Borough_Coordinates
# 0  ['cafe', 'food', 'point_of_interest', 'establi...     51.5607, 0.1557
# ...

# %%
SQL CODE

CREATE TABLE CAFE (
Cafe_Name VARCHAR(255),
Place_Id VARCHAR(255),
Cafe_Coordinates VARCHAR(255),
Vicinity VARCHAR(255),
Cafe_Types VARCHAR(255),
Borough_Coordinates VARCHAR(255),
PRIMARY KEY(Place_Id),
FOREIGN KEY(Borough_Coordinates) REFERENCES()

# %%
df1 = pd.read_csv('csv/rating_entity.csv')
df1.head()
# Out:
#                       Place_Id  Rating  Number_Ratings
# 0  ChIJP5iSZRul2EcRuLlMBSZy-JY     4.0              40
# 1  ChIJdwGW-HOl2EcRkRKhL91oI_s     3.6             822
# 2  ChIJfRvpP_yk2EcRMHJ8P6PE448     3.6             824
# 3  ChIJbz00eCW72EcRv-wkpDkmsGQ     3.8             391
# 4  ChIJmSZw6z2l2EcRpS8prTdOqic     4.3              91

# %%
df1 = pd.read_csv('csv/review_entity.csv')
df1.head()
# Out:
#                       Place_Id                     Review_Id  \
# 0  ChIJP5iSZRul2EcRuLlMBSZy-JY  ChIJP5iSZRul2EcRuLlMBSZy-JY1
# 1  ChIJP5iSZRul2EcRuLlMBSZy-JY  ChIJP5iSZRul2EcRuLlMBSZy-JY2
# 2  ChIJP5iSZRul2EcRuLlMBSZy-JY  ChIJP5iSZRul2EcRuLlMBSZy-JY3
# 3  ChIJP5iSZRul2EcRuLlMBSZy-JY  ChIJP5iSZRul2EcRuLlMBSZy-JY4
# 4  ChIJP5iSZRul2EcRuLlMBSZy-JY  ChIJP5iSZRul2EcRuLlMBSZy-JY5
#
#         Author_Name                                        Review_Text  \
# 0  Terence j Cleary  First time here, amazing food spotlessly clean...
# 1     George Reeves  Not even a cafe. Thery sell shop brought bread...
# 2            Jack J  I used to eat here often but it has slowly dec...
# 3     Samina Barker  Lovely friendly staff, clean cafe and quick se...
# 4       Jaime Wiles  Nice coffee.\nFriendly staff.\n\nDidn't eat an...
#
#   Relative_Time_Description
# 0               a month ago
# 1                a year ago
# 2                a year ago
# 3                a year ago
# ...
