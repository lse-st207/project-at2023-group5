# 2        51.4549, 0.1505
# 3       51.5588, -0.2817
# 4        51.4039, 0.0198
# 5        51.529, -0.1255
# 6       51.3714, -0.0977
# 7        51.513, -0.3089
# 8       51.6538, -0.0799
# 9        51.4892, 0.0648
# 10       51.545, -0.0553
# 11      51.4927, -0.2339
# 12         51.6, -0.1119
# 13      51.5898, -0.3346
# 14       51.5812, 0.1837
# 15       51.5441, -0.476
# 16       51.4746, -0.368
# 17      51.5416, -0.1022
# 18       51.502, -0.1947
# 19      51.4085, -0.3064
# 20      51.4607, -0.1163
# 21      51.4452, -0.0209
# 22      51.4014, -0.1958
# 23       51.5077, 0.0469
# 24        51.559, 0.0741
# 25       51.4479, -0.326
# 26      51.5035, -0.0804
# 27      51.3618, -0.1945
# 28      51.5099, -0.0059
# 29      51.5908, -0.0134
# 30       51.4567, -0.191
# 31      51.4973, -0.1372
# 32      51.5077, -0.0953

# %%
pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from googlemaps) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import requests
from datetime import datetime

# %%
import json
import requests

# %%
with open('keys.json') as f:
    keys = json.load(f)
api_key = keys['googleapi']['api_key']

# %%
# initialize the Google Maps client
gmaps = googlemaps.Client(key=api_key)

# %%
# Function to fetch location details using latitude and longitude

def get_location_details(loc):
    locations = []
    
    places = gmaps.places_nearby(
    location=loc,
    radius=5000,  # Search radius in meters (adjust as needed)
    type="cafe")
        
    for place in places['results']:
        location_data = {
            'Name': place['name'],
            'Geometry': place['geometry'],
            'Place ID': place['place_id'],
            'Types': place['types'],
            'Rating': place.get('rating'),
            'User Ratings Total': place.get('user_ratings_total'),
            'Vicinity': place.get('vicinity')
        }
        locations.append(location_data)
    
    return pd.DataFrame(locations)

# %%
df_list = []

for coord in df['Converted_Coordinates']:
    other = get_location_details(coord)
    df_list.append(other)

# %%
new_df = pd.concat(df_list, ignore_index=True)
new_df
# Out:
#                                Name  \
# 0                      Take a Break
# 1          Asda Dagenham Superstore
# 2    Becontree Heath Leisure Centre
# 3       Harrow Lodge Leisure Centre
# 4       Eastbrook Cafe & Restuarant
# ..                              ...
# 655             The British Library
# 656                  The Table Café
# 657                     Curzon Soho
# 658              ODEON Surrey Quays
# 659                     Swan London
#
#                                               Geometry  \
# 0    {'location': {'lat': 51.55102600000001, 'lng':...
# 1    {'location': {'lat': 51.5301912, 'lng': 0.1422...
# 2    {'location': {'lat': 51.5609465, 'lng': 0.1488...
# 3    {'location': {'lat': 51.5632907, 'lng': 0.2089...
# 4    {'location': {'lat': 51.5508213, 'lng': 0.1614...
# ..                                                 ...
# 655  {'location': {'lat': 51.52997169999999, 'lng':...
# 656  {'location': {'lat': 51.5054844, 'lng': -0.099...
# 657  {'location': {'lat': 51.5127004, 'lng': -0.130...
# 658  {'location': {'lat': 51.4959322, 'lng': -0.044...
# 659  {'location': {'lat': 51.5082418, 'lng': -0.096...
#
#                         Place ID  \
# 0    ChIJP5iSZRul2EcRuLlMBSZy-JY
# 1    ChIJdwGW-HOl2EcRkRKhL91oI_s
# 2    ChIJfRvpP_yk2EcRMHJ8P6PE448
# 3    ChIJbz00eCW72EcRv-wkpDkmsGQ
# 4    ChIJmSZw6z2l2EcRpS8prTdOqic
# ..                           ...
# 655  ChIJlRMXcDsbdkgRJdsP3nlUkBg
# 656  ChIJbc-9tKgEdkgR2qNGtGhKWLc
# 657  ChIJR_tP9tIEdkgR50LK64QCsck
# 658  ChIJGTY0qN8CdkgR5fzIXjzgJsY
# 659  ChIJ70dbCqkEdkgR_2rXCHnP0aQ
#
#                                                  Types  Rating  \
# 0       [cafe, food, point_of_interest, establishment]     4.0
# 1    [supermarket, atm, pharmacy, gas_station, cafe...     3.6
# 2    [gym, cafe, school, food, point_of_interest, h...     3.6
# 3    [gym, cafe, general_contractor, school, food, ...     3.8
# 4    [restaurant, meal_delivery, cafe, meal_takeawa...     4.3
# ..                                                 ...     ...
# 655  [library, tourist_attraction, cafe, store, res...     4.5
# 656  [cafe, restaurant, food, point_of_interest, es...     4.3
# 657  [movie_theater, cafe, restaurant, food, bar, p...     4.5
# 658  [movie_theater, cafe, store, food, point_of_in...     3.9
# 659  [restaurant, cafe, food, bar, point_of_interes...     4.3
#
#      User Ratings Total                                         Vicinity
# 0                  40.0                         244 Oxlow Lane, Dagenham
# 1                 820.0                   Merrielands Crescent, Dagenham
# 2                 824.0                           Althorne Way, Dagenham
# 3                 391.0                      Hornchurch Road, Hornchurch
# 4                  91.0                 264 Rainham Road South, Dagenham
# ..                  ...                                              ...
# 655              2635.0                           96 Euston Road, London
# 656              1981.0                      83 Southwark Street, London
# 657              1585.0                    99 Shaftesbury Avenue, London
# 658              2958.0  Surrey Quays Leisure Park, Redriff Road, London
# 659              3036.0              21 New Globe Walk, Bankside, London
#
# [660 rows x 7 columns]

# %% [markdown]
# ## data cleaning

# %%
new_df[['lat', 'lng']] = new_df['Geometry'].apply(lambda x: pd.Series({'lat': x['location']['lat'], 'lng': x['location']['lng']}))
new_df = new_df.drop_duplicates(subset=['lat', 'lng'], keep='first') #drop entries with the same geometry
new_df = new_df.drop(['Geometry'], axis=1)

#list of cafes near the boroughs
new_df
# Out:
#                                Name                     Place ID  \
# 0                      Take a Break  ChIJP5iSZRul2EcRuLlMBSZy-JY
# 1          Asda Dagenham Superstore  ChIJdwGW-HOl2EcRkRKhL91oI_s
# 2    Becontree Heath Leisure Centre  ChIJfRvpP_yk2EcRMHJ8P6PE448
# 3       Harrow Lodge Leisure Centre  ChIJbz00eCW72EcRv-wkpDkmsGQ
# 4       Eastbrook Cafe & Restuarant  ChIJmSZw6z2l2EcRpS8prTdOqic
# ..                              ...                          ...
# 610          Jack's at the Junction  ChIJ3-4QRpgFdkgR7Ufu_ZL5qMg
# 612                    Pottery Cafe  ChIJk6UKjpwPdkgRCuZJf5s7aos
# 613    GAIL's Bakery Northcote Road  ChIJeyNpaJYFdkgRzUn4MrNtQyw
# 614         The Kensington Creperie  ChIJmeHbYUIFdkgRjx3BnN1Qvk8
# 619               GAZETTE BATTERSEA  ChIJHSvImYYFdkgRp4X4Jsv1rqI
#
#                                                  Types  Rating  \
# 0       [cafe, food, point_of_interest, establishment]     4.0
# 1    [supermarket, atm, pharmacy, gas_station, cafe...     3.6
# 2    [gym, cafe, school, food, point_of_interest, h...     3.6
# 3    [gym, cafe, general_contractor, school, food, ...     3.8
# 4    [restaurant, meal_delivery, cafe, meal_takeawa...     4.3
# ..                                                 ...     ...
# 610  [cafe, restaurant, food, point_of_interest, st...     4.3
# 612  [cafe, food, point_of_interest, store, establi...     4.6
# 613  [bakery, meal_delivery, cafe, restaurant, food...     3.8
# 614  [cafe, restaurant, food, point_of_interest, st...     3.7
# 619  [cafe, bar, restaurant, food, point_of_interes...     4.3
#
#      User Ratings Total                                         Vicinity  \
# 0                  40.0                         244 Oxlow Lane, Dagenham
# 1                 820.0                   Merrielands Crescent, Dagenham
# 2                 824.0                           Althorne Way, Dagenham
# 3                 391.0                      Hornchurch Road, Hornchurch
# 4                  91.0                 264 Rainham Road South, Dagenham
# ..                  ...                                              ...
# 610               936.0                        252 Lavender Hill, London
# 612               179.0                          735 Fulham Road, London
# 613               450.0                        64 Northcote Road, London
# 614              1669.0                      2-4 Exhibition Road, London
# 619               590.0  Unit 79, Sherwood Court, Chatfield Road, London
#
#            lat       lng
# 0    51.551026  0.154796
# 1    51.530191  0.142217
# 2    51.560947  0.148899
# 3    51.563291  0.208940
# 4    51.550821  0.161418
# ..         ...       ...
# 610  51.464008 -0.166480
# 612  51.476860 -0.202447
# 613  51.458499 -0.166277
# 614  51.494773 -0.173204
# 619  51.465811 -0.182253
#
# [451 rows x 8 columns]

# %%
# Build the Place Details URL
for index, row in new_df.iterrows():
    place_id = row['Place ID']
    cafe_name = row['Name']
    # Extract the first two letters of the cafe name
    prefix = place_id
    
    place_details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=reviews&key={api_key}"

    # Send the request and get the response
    response = requests.get(place_details_url)
    details = response.json()

    # Extract the reviews (ONLY TOP 5 ranked my relevance, that are most informative and helpful for users looking for insights)
    reviews = details['result'].get('reviews', [])
    review_counter = 1
    
    # Process each review
    for review in reviews:
        # Generate review_id
        review_id = f"{prefix}{review_counter}"
        
        # Retrieve author's name and when it is written
        author_name = review.get('author_name')
        relative_time_description = review.get('relative_time_description')
        review_counter += 1
        
        print(f"Review_ID: {review_id}, Author: {author_name}, Time: {relative_time_description}")
    print(f"{cafe_name}------------------------------------------------------------------")
# Out:
# Review_ID: ChIJP5iSZRul2EcRuLlMBSZy-JY1, Author: Terence j Cleary, Time: a month ago
# Review_ID: ChIJP5iSZRul2EcRuLlMBSZy-JY2, Author: George Reeves, Time: a year ago
# Review_ID: ChIJP5iSZRul2EcRuLlMBSZy-JY3, Author: Jack J, Time: a year ago
# Review_ID: ChIJP5iSZRul2EcRuLlMBSZy-JY4, Author: Samina Barker, Time: a year ago
# Review_ID: ChIJP5iSZRul2EcRuLlMBSZy-JY5, Author: Jaime Wiles, Time: 2 years ago
# Take a Break------------------------------------------------------------------
# Review_ID: ChIJdwGW-HOl2EcRkRKhL91oI_s1, Author: Salim Patel, Time: 7 months ago
# Review_ID: ChIJdwGW-HOl2EcRkRKhL91oI_s2, Author: The Throwback Guy, Time: 4 months ago
# Review_ID: ChIJ6-KsMLWv2EcRGwmnwCigq8w2, Author: Louise Cotton, Time: 6 months ago
# Review_ID: ChIJ6-KsMLWv2EcRGwmnwCigq8w3, Author: Glynis Brown, Time: a year ago
# Review_ID: ChIJ6-KsMLWv2EcRGwmnwCigq8w4, Author: Sunita, Time: 3 months ago
# Review_ID: ChIJ6-KsMLWv2EcRGwmnwCigq8w5, Author: HannahMarie Day, Time: 3 months ago
# Munchies------------------------------------------------------------------
# Review_ID: ChIJ-9mlxyKu2EcRVHxnICHG6GI1, Author: Cafe Crusader, Time: 11 months ago
# Review_ID: ChIJ-9mlxyKu2EcRVHxnICHG6GI2, Author: david sanders, Time: 4 months ago
# Review_ID: ChIJ-9mlxyKu2EcRVHxnICHG6GI3, Author: adrian gibson, Time: 3 months ago
# Review_ID: ChIJ-9mlxyKu2EcRVHxnICHG6GI4, Author: Emma-Louise Chamberlain, Time: a year ago
# Review_ID: ChIJ-9mlxyKu2EcRVHxnICHG6GI5, Author: Colin Fowler, Time: a week ago
# Kenny's Cafe------------------------------------------------------------------
# Review_ID: ChIJ04VP1dqu2EcRajwudSrobUY1, Author: Beth Maxim, Time: a month ago
# Review_ID: ChIJ04VP1dqu2EcRajwudSrobUY2, Author: Pallabi Roy Sonkovics, Time: a year ago
# Review_ID: ChIJ04VP1dqu2EcRajwudSrobUY3, Author: Keith Allen, Time: a week ago
# Review_ID: ChIJ04VP1dqu2EcRajwudSrobUY4, Author: billy boy Moldon, Time: a year ago
# Review_ID: ChIJ04VP1dqu2EcRajwudSrobUY5, Author: Honest Review, Time: 5 months ago
# Koffi Pot------------------------------------------------------------------
# Review_ID: ChIJ69rfpV6u2EcReSrHDYdB3rI1, Author: M J (Tinks), Time: a week ago
# Review_ID: ChIJ69rfpV6u2EcReSrHDYdB3rI2, Author: Padma Ale, Time: 3 weeks ago
# Review_ID: ChIJ69rfpV6u2EcReSrHDYdB3rI3, Author: Mishka K, Time: a year ago
# Review_ID: ChIJ69rfpV6u2EcReSrHDYdB3rI4, Author: MemLordGuy, Time: 5 months ago
# Review_ID: ChIJ69rfpV6u2EcReSrHDYdB3rI5, Author: Everest House ltd, Time: 3 weeks ago
# Mooboo Bexleyheath------------------------------------------------------------------
# Review_ID: ChIJFaDu0F6u2EcRDnSTuG_K3VQ1, Author: Natasha B, Time: in the last week
# Review_ID: ChIJFaDu0F6u2EcRDnSTuG_K3VQ2, Author: Obreja Vladimir, Time: a month ago
# Review_ID: ChIJFaDu0F6u2EcRDnSTuG_K3VQ3, Author: Sal H, Time: 4 months ago
# Review_ID: ChIJFaDu0F6u2EcRDnSTuG_K3VQ4, Author: sue sullivan, Time: 11 months ago
# Review_ID: ChIJFaDu0F6u2EcRDnSTuG_K3VQ5, Author: Lia Harlin, Time: 6 months ago
# Caffè Nero------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       8 place_details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=reviews&key={api_key}"
#      10 # Send the request and get the response
# ---> 11 response = requests.get(place_details_url)
#      12 details = response.json()
#      14 # Extract the reviews (ONLY TOP 5 ranked my relevance, that are most informative and helpful for users looking for insights)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# import sqlite3
#
# # Establish a database connection
# conn = sqlite3.connect('Cafe_Database.db')
# cursor = conn.cursor()
#
# # Function to store reviews
# def store_review(place_id, review_data):
#     """
#     place_id: string to retrieve the each cafe's place id
#     review_data: dict, reviews and its info for each place id
#     """
#     # SQL query to insert review data into the 'reviews' table
#     query = '''INSERT INTO reviews (place_id, Review_ID, Author_Name, Relative_Time_Description)
#                VALUES (?, ?, ?, ?)'''
#     # Execute the query with the review data
#     cursor.execute(query, (place_id, review_data['review_id'], review_data['author_name'],
#                            review_data['relative_time_description']))
#     # Commit the changes
#     conn.commit()

# %% [markdown]
# for place_id in new_df['Place ID']:
#     place_details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=reviews&key={api_key}"
#     for review in reviews:
#         # Extract needed review data
#         review_data = {
#             'author_name': review.get('author_name'),
#             'relative_time_description': review.get('relative_time_description'),
#         }
#
#         # Store the review_data in database
#         database.store_review(place_id, review_data)

# %% [markdown]
# # Data using top_100.csv

# %%
import pandas as pd

# %%
shop_df = pd.read_csv('top_100.csv')
shop_df = shop_df[shop_df['category']=='Coffee Shop']
shop_df
# Out:
#                     Borough       Lat      Lng            name        lat  \
# 0     Barking and Dagenham   51.57478  0.17441    Costa Coffee  51.576890
# 4     Barking and Dagenham   51.57478  0.17441    Costa Coffee  51.576481
# 15    Barking and Dagenham   51.57478  0.17441       Starbucks  51.576281
# 20    Barking and Dagenham   51.57478  0.17441  Harris + Hoole  51.565614
# 23    Barking and Dagenham   51.57478  0.17441       Starbucks  51.577947
# ...                     ...       ...      ...             ...        ...
# 3067         City of London  51.52050 -0.09743         Rosslyn  51.512574
# 3076         City of London  51.52050 -0.09743   Catalyst Cafe  51.519705
# 3079         City of London  51.52050 -0.09743        The Wren  51.512049
# 3082         City of London  51.52050 -0.09743           Briki  51.526369
# 3098         City of London  51.52050 -0.09743   Origin Coffee  51.526347
#
#            lng     category
# 0     0.179497  Coffee Shop
# 4     0.182448  Coffee Shop
# 15    0.181187  Coffee Shop
# 20    0.191278  Coffee Shop
# 23    0.182874  Coffee Shop
# ...        ...          ...
# 3067 -0.093381  Coffee Shop
# 3076 -0.112052  Coffee Shop
# 3079 -0.096799  Coffee Shop
# 3082 -0.108318  Coffee Shop
# 3098 -0.081204  Coffee Shop
#
# [230 rows x 7 columns]

# %%
# Function to fetch location details using latitude and longitude
def get_shop_details(lat, lng):
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=coffee%2shop&inputtype=textquery&locationbias=circle%3A2000%{lat}%2C{lng}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        location_data = response.json()
        return location_data
    else:
        return None

# %%
url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=coffee%2shop&inputtype=textquery&locationbias=circle%3A2000%51.576890%2C0.179497&key=AIzaSyBxyO-AntGhj6usDddayBdYSNnFoEs4Bo8"
response = requests.get(url)
response.json()['candidates']
# Out:
# []

# %%
shop_df['location_details'] = shop_df.apply(lambda row: get_location_detail(row['lat'], row['lng']), axis=1)
shop_df
