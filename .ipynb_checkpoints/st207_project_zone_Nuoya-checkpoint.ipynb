# %%
import json
import requests
from bs4 import BeautifulSoup # library for web scrapping

# %%
# import api: google API testing

with open('keys.json') as f:
    keys = json.load(f)
api_key = keys['geoapify']['api_key']

# %%
url = f'https://api.geoapify.com/v2/places?categories=catering.cafe&filter=geometry:127166464f731937062ce98ae8e538e0&bias=proximity:-0.1137266,51.5195982&limit=500&apiKey={api_key}'

# get up to 500 of 30-min walk cafe from center of holborn
response = requests.get(url)
if response.status_code == 200:
    print("API key is valid!")
else:
    print("API key is not valid.")

# %%
# show the 1st result
sample_data = json.loads(requests.get(url).text)
extracted_info = {
    "name": response["features"][0]["properties"]["name"],
    "postcode": response["features"][0]["properties"]["postcode"],
    "place_id": response["features"][0]["properties"]["place_id"]
}
extracted_info

# %% [markdown]
# # import api: geoapify API testing
#
# with open('keys.json') as f:
#     keys = json.load(f)
# api_key = keys['google']['api_key']
#
# url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
# params = {'location': '51.510244%2C-0.12571990', 'query': 'cafe', 'radius': '10000', 'key': api_key}
# response = requests.get(url,params = params)
#
# if response.status_code == 200:
#     print("API key is valid!")
# else:
#     print("API key is not valid.")

# %%
import requests
from bs4 import BeautifulSoup # library for web scrapping
import pandas as pd
import re


# get coordinates of every Boroughs in London (32 of them) and City of London --> total 33
# getting data from internet, URL of the Wikipedia page containing the list of London boroughs
wiki_url = 'https://en.wikipedia.org/wiki/List_of_London_boroughs'
raw_wiki_page= requests.get(wiki_url, timeout = 2).text

soup = BeautifulSoup(raw_wiki_page, 'html.parser')

# Find the table containing the list of boroughs
table = soup.find_all('table', {'class': 'wikitable sortable'})[0]
# Create a DataFrame from the table
London_table = pd.read_html(str(table), index_col=None, header=0)[0]
London_table
# Out:
#                            Borough     Inner Status  \
# 0     Barking and Dagenham[note 1]       NaN    NaN
# 1                           Barnet       NaN    NaN
# 2                           Bexley       NaN    NaN
# 3                            Brent       NaN    NaN
# 4                          Bromley       NaN    NaN
# 5                           Camden       NaN    NaN
# 6                          Croydon       NaN    NaN
# 7                           Ealing       NaN    NaN
# 8                          Enfield       NaN    NaN
# 9                Greenwich[note 2]  [note 3]  Royal
# 10                         Hackney       NaN    NaN
# 11  Hammersmith and Fulham[note 4]       NaN    NaN
# 12                        Haringey  [note 3]    NaN
# 13                          Harrow       NaN    NaN
# 14                        Havering       NaN    NaN
# 15                      Hillingdon       NaN    NaN
# 16                        Hounslow       NaN    NaN
# ...

# %% [markdown]
# ## Data cleaning

# %%
# Iterate over the 'Borough' column and clean each entry
cleaned_boroughs = []
for borough in London_table['Borough']:
    cleaned_name = borough.split('[')[0].strip()
    cleaned_boroughs.append(cleaned_name)

# Updating existing 'Borough' column
London_table['Borough'] = cleaned_boroughs
London_table
# Out:
#                    Borough     Inner Status  \
# 0     Barking and Dagenham       NaN    NaN
# 1                   Barnet       NaN    NaN
# 2                   Bexley       NaN    NaN
# 3                    Brent       NaN    NaN
# 4                  Bromley       NaN    NaN
# 5                   Camden       NaN    NaN
# 6                  Croydon       NaN    NaN
# 7                   Ealing       NaN    NaN
# 8                  Enfield       NaN    NaN
# 9                Greenwich  [note 3]  Royal
# 10                 Hackney       NaN    NaN
# 11  Hammersmith and Fulham       NaN    NaN
# 12                Haringey  [note 3]    NaN
# 13                  Harrow       NaN    NaN
# 14                Havering       NaN    NaN
# 15              Hillingdon       NaN    NaN
# 16                Hounslow       NaN    NaN
# 17               Islington       NaN    NaN
# 18  Kensington and Chelsea       NaN  Royal
# 19    Kingston upon Thames       NaN  Royal
# ...

# %%
import re
original_string = London_table['Co-ordinates'][0]
pattern = r'\d{2}°\d{2}′\d{2}″N \d{1,2}°\d{2}′\d{2}″E.*?\d{2}\.\d+°N \d{1,3}\.\d+°E'

# Search for the pattern in the original string
match = re.search(pattern, original_string)

# Extract the matched part
result = match.group() if match else 'No match found'

London_table['Co-ordinates'][0] = result
London_table
# Out:
# /var/folders/l6/dfw3zk0s5tbdf21c6512l8k00000gn/T/ipykernel_76211/2199699111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   London_table['Co-ordinates'][0] = result
#                    Borough     Inner Status  \
# 0     Barking and Dagenham       NaN    NaN
# 1                   Barnet       NaN    NaN
# 2                   Bexley       NaN    NaN
# 3                    Brent       NaN    NaN
# 4                  Bromley       NaN    NaN
# 5                   Camden       NaN    NaN
# 6                  Croydon       NaN    NaN
# 7                   Ealing       NaN    NaN
# 8                  Enfield       NaN    NaN
# 9                Greenwich  [note 3]  Royal
# 10                 Hackney       NaN    NaN
# 11  Hammersmith and Fulham       NaN    NaN
# ...

# %%
# keep only borough names and coordinates info
new_london_table = London_table[['Borough', 'Co-ordinates']]

# add data of City of London
new_data = {
    'Borough': 'City of London',
    'Co-ordinates': '51°30′28″N 0°05′43″W / 51.5077°N 0.0953°W'}
new_london_table = new_london_table.append(new_data, ignore_index=True)

# Display the new DataFrame
new_london_table
# Out:
# /var/folders/l6/dfw3zk0s5tbdf21c6512l8k00000gn/T/ipykernel_76211/677732019.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_london_table = new_london_table.append(new_data, ignore_index=True)
#                    Borough                                 Co-ordinates
# 0     Barking and Dagenham  51°33′39″N 0°09′21″E﻿ / ﻿51.5607°N 0.1557°E
# 1                   Barnet  51°37′31″N 0°09′06″W﻿ / ﻿51.6252°N 0.1517°W
# 2                   Bexley  51°27′18″N 0°09′02″E﻿ / ﻿51.4549°N 0.1505°E
# 3                    Brent  51°33′32″N 0°16′54″W﻿ / ﻿51.5588°N 0.2817°W
# 4                  Bromley  51°24′14″N 0°01′11″E﻿ / ﻿51.4039°N 0.0198°E
# 5                   Camden  51°31′44″N 0°07′32″W﻿ / ﻿51.5290°N 0.1255°W
# 6                  Croydon  51°22′17″N 0°05′52″W﻿ / ﻿51.3714°N 0.0977°W
# 7                   Ealing  51°30′47″N 0°18′32″W﻿ / ﻿51.5130°N 0.3089°W
# ...

# %%
# only keep the second Decimal Format and convert to plus minus form (i.e., replacing 'N' and 'E' with positive values and 'S' and 'W' with negative values) as this is what geoapify using

def convert_to_decimal(coord):
    """
    This function is to convert DSM into convert coordinate string to decimal with plus-minus form
    coord: string
    return: string in longtitude and latitude format
    """
    match = re.search(r'(\d+\.\d+)°([NS])\s+(\d+\.\d+)°([EW])', coord)
    if match:
        lat, lat_hemi, lon, lon_hemi = match.groups()
        lat = float(lat) * (-1 if lat_hemi == 'S' else 1)
        lon = float(lon) * (-1 if lon_hemi == 'W' else 1)
        return f"{lat}, {lon}"
    return 'No match found'

new_london_table['Converted_Coordinates'] = new_london_table['Co-ordinates'].apply(lambda x: convert_to_decimal(x))
new_london_table
# Out:
#                    Borough                                 Co-ordinates  \
# 0     Barking and Dagenham  51°33′39″N 0°09′21″E﻿ / ﻿51.5607°N 0.1557°E
# 1                   Barnet  51°37′31″N 0°09′06″W﻿ / ﻿51.6252°N 0.1517°W
# 2                   Bexley  51°27′18″N 0°09′02″E﻿ / ﻿51.4549°N 0.1505°E
# 3                    Brent  51°33′32″N 0°16′54″W﻿ / ﻿51.5588°N 0.2817°W
# 4                  Bromley  51°24′14″N 0°01′11″E﻿ / ﻿51.4039°N 0.0198°E
# 5                   Camden  51°31′44″N 0°07′32″W﻿ / ﻿51.5290°N 0.1255°W
# 6                  Croydon  51°22′17″N 0°05′52″W﻿ / ﻿51.3714°N 0.0977°W
# 7                   Ealing  51°30′47″N 0°18′32″W﻿ / ﻿51.5130°N 0.3089°W
# 8                  Enfield  51°39′14″N 0°04′48″W﻿ / ﻿51.6538°N 0.0799°W
# 9                Greenwich  51°29′21″N 0°03′53″E﻿ / ﻿51.4892°N 0.0648°E
# 10                 Hackney  51°32′42″N 0°03′19″W﻿ / ﻿51.5450°N 0.0553°W
# 11  Hammersmith and Fulham  51°29′34″N 0°14′02″W﻿ / ﻿51.4927°N 0.2339°W
# ...
