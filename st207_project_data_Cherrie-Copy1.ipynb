# 4        51.4039, 0.0198
# 5        51.529, -0.1255
# 6       51.3714, -0.0977
# 7        51.513, -0.3089
# 8       51.6538, -0.0799
# 9        51.4892, 0.0648
# 10       51.545, -0.0553
# 11      51.4927, -0.2339
# 12         51.6, -0.1119
# 13      51.5898, -0.3346
# 14       51.5812, 0.1837
# 15       51.5441, -0.476
# 16       51.4746, -0.368
# 17      51.5416, -0.1022
# 18       51.502, -0.1947
# 19      51.4085, -0.3064
# 20      51.4607, -0.1163
# 21      51.4452, -0.0209
# 22      51.4014, -0.1958
# 23       51.5077, 0.0469
# 24        51.559, 0.0741
# 25       51.4479, -0.326
# 26      51.5035, -0.0804
# 27      51.3618, -0.1945
# 28      51.5099, -0.0059
# 29      51.5908, -0.0134
# 30       51.4567, -0.191
# 31      51.4973, -0.1372
# 32      51.5077, -0.0953

# %%
pip install -U googlemaps
# Out:
# Requirement already satisfied: googlemaps in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from googlemaps) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kannuoya/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.20.0->googlemaps) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import googlemaps
import requests
from datetime import datetime

# %%
import json
import requests

# %%
with open('keys.json') as f:
    keys = json.load(f)
api_key = keys['googleapi']['api_key']

# %%
# initialize the Google Maps client
gmaps = googlemaps.Client(key=api_key)

# %%
# Function to fetch location details using latitude and longitude

def get_location_details(loc):
    locations = []
    
    places = gmaps.places_nearby(
    location=loc,
    radius=5000,  # Search radius in meters (adjust as needed)
    type="cafe")
        
    for place in places['results']:
        location_data = {
            'Name': place['name'],
            'Geometry': place['geometry'],
            'Place ID': place['place_id'],
            'Types': place['types'],
            'Rating': place.get('rating'),
            'User Ratings Total': place.get('user_ratings_total'),
            'Vicinity': place.get('vicinity')
        }
        locations.append(location_data)
    
    return pd.DataFrame(locations)

# %%
df_list = []

for coord in df['Converted_Coordinates']:
    other = get_location_details(coord)
    df_list.append(other)

# %%
new_df = pd.concat(df_list, ignore_index=True)
new_df
# Out:
#                                Name  \
# 0                      Take a Break
# 1          Asda Dagenham Superstore
# 2    Becontree Heath Leisure Centre
# 3       Harrow Lodge Leisure Centre
# 4       Eastbrook Cafe & Restuarant
# ..                              ...
# 655             The British Library
# 656                  The Table Café
# 657                     Curzon Soho
# 658              ODEON Surrey Quays
# 659                     Swan London
#
#                                               Geometry  \
# 0    {'location': {'lat': 51.55102600000001, 'lng':...
# 1    {'location': {'lat': 51.529501, 'lng': 0.13963...
# 2    {'location': {'lat': 51.5609465, 'lng': 0.1488...
# 3    {'location': {'lat': 51.5632907, 'lng': 0.2089...
# 4    {'location': {'lat': 51.5508213, 'lng': 0.1614...
# ..                                                 ...
# 655  {'location': {'lat': 51.52997169999999, 'lng':...
# 656  {'location': {'lat': 51.5054844, 'lng': -0.099...
# 657  {'location': {'lat': 51.5127004, 'lng': -0.130...
# 658  {'location': {'lat': 51.4959322, 'lng': -0.044...
# 659  {'location': {'lat': 51.5082418, 'lng': -0.096...
#
#                         Place ID  \
# 0    ChIJP5iSZRul2EcRuLlMBSZy-JY
# 1    ChIJdwGW-HOl2EcRkRKhL91oI_s
# 2    ChIJfRvpP_yk2EcRMHJ8P6PE448
# 3    ChIJbz00eCW72EcRv-wkpDkmsGQ
# 4    ChIJmSZw6z2l2EcRpS8prTdOqic
# ..                           ...
# 655  ChIJlRMXcDsbdkgRJdsP3nlUkBg
# 656  ChIJbc-9tKgEdkgR2qNGtGhKWLc
# 657  ChIJR_tP9tIEdkgR50LK64QCsck
# 658  ChIJGTY0qN8CdkgR5fzIXjzgJsY
# 659  ChIJ70dbCqkEdkgR_2rXCHnP0aQ
#
#                                                  Types  Rating  \
# 0       [cafe, food, point_of_interest, establishment]     4.0
# 1    [supermarket, atm, pharmacy, grocery_or_superm...     3.6
# 2    [gym, cafe, school, food, point_of_interest, h...     3.6
# 3    [gym, cafe, general_contractor, school, food, ...     3.8
# 4    [restaurant, meal_delivery, meal_takeaway, caf...     4.3
# ..                                                 ...     ...
# 655  [library, tourist_attraction, cafe, restaurant...     4.5
# 656  [cafe, restaurant, point_of_interest, food, es...     4.3
# 657  [movie_theater, bar, cafe, restaurant, point_o...     4.5
# 658  [movie_theater, cafe, point_of_interest, store...     3.9
# 659  [restaurant, bar, cafe, point_of_interest, foo...     4.3
#
#      User Ratings Total                                         Vicinity
# 0                  40.0                         244 Oxlow Lane, Dagenham
# 1                 819.0                   Merrielands Crescent, Dagenham
# 2                 824.0                           Althorne Way, Dagenham
# 3                 391.0                      Hornchurch Road, Hornchurch
# 4                  91.0                 264 Rainham Road South, Dagenham
# ..                  ...                                              ...
# 655              2625.0                           96 Euston Road, London
# 656              1977.0                      83 Southwark Street, London
# 657              1580.0                    99 Shaftesbury Avenue, London
# 658              2953.0  Surrey Quays Leisure Park, Redriff Road, London
# 659              3030.0              21 New Globe Walk, Bankside, London
#
# [660 rows x 7 columns]

# %% [markdown]
# ## data cleaning

# %%
new_df[['lat', 'lng']] = new_df['Geometry'].apply(lambda x: pd.Series({'lat': x['location']['lat'], 'lng': x['location']['lng']}))
new_df = new_df.drop_duplicates(subset=['lat', 'lng'], keep='first') 

#drop entries with the same geometry
new_df = new_df.drop(['Geometry'], axis=1)

#list of cafes near the boroughs
new_df
# Out:
#                                Name                     Place ID  \
# 0                      Take a Break  ChIJP5iSZRul2EcRuLlMBSZy-JY
# 1          Asda Dagenham Superstore  ChIJdwGW-HOl2EcRkRKhL91oI_s
# 2    Becontree Heath Leisure Centre  ChIJfRvpP_yk2EcRMHJ8P6PE448
# 3       Harrow Lodge Leisure Centre  ChIJbz00eCW72EcRv-wkpDkmsGQ
# 4       Eastbrook Cafe & Restuarant  ChIJmSZw6z2l2EcRpS8prTdOqic
# ..                              ...                          ...
# 610          Jack's at the Junction  ChIJ3-4QRpgFdkgR7Ufu_ZL5qMg
# 612                    Pottery Cafe  ChIJk6UKjpwPdkgRCuZJf5s7aos
# 613    GAIL's Bakery Northcote Road  ChIJeyNpaJYFdkgRzUn4MrNtQyw
# 614         The Kensington Creperie  ChIJmeHbYUIFdkgRjx3BnN1Qvk8
# 619               GAZETTE BATTERSEA  ChIJHSvImYYFdkgRp4X4Jsv1rqI
#
#                                                  Types  Rating  \
# 0       [cafe, food, point_of_interest, establishment]     4.0
# 1    [supermarket, atm, pharmacy, grocery_or_superm...     3.6
# 2    [gym, cafe, school, food, point_of_interest, h...     3.6
# 3    [gym, cafe, general_contractor, school, food, ...     3.8
# 4    [restaurant, meal_delivery, meal_takeaway, caf...     4.3
# ..                                                 ...     ...
# 610  [cafe, store, restaurant, food, point_of_inter...     4.3
# 612  [cafe, store, food, point_of_interest, establi...     4.6
# 613  [bakery, meal_delivery, cafe, store, restauran...     3.8
# 614  [cafe, store, restaurant, food, point_of_inter...     3.7
# 619  [cafe, bar, restaurant, food, point_of_interes...     4.3
#
#      User Ratings Total                                         Vicinity  \
# 0                  40.0                         244 Oxlow Lane, Dagenham
# 1                 819.0                   Merrielands Crescent, Dagenham
# 2                 824.0                           Althorne Way, Dagenham
# 3                 391.0                      Hornchurch Road, Hornchurch
# 4                  91.0                 264 Rainham Road South, Dagenham
# ..                  ...                                              ...
# 610               936.0                        252 Lavender Hill, London
# 612               178.0                          735 Fulham Road, London
# 613               450.0                        64 Northcote Road, London
# 614              1667.0                      2-4 Exhibition Road, London
# 619               590.0  Unit 79, Sherwood Court, Chatfield Road, London
#
#            lat       lng
# 0    51.551026  0.154796
# 1    51.529501  0.139635
# 2    51.560947  0.148899
# 3    51.563291  0.208940
# 4    51.550821  0.161418
# ..         ...       ...
# 610  51.464008 -0.166480
# 612  51.476860 -0.202447
# 613  51.458499 -0.166277
# 614  51.494773 -0.173204
# 619  51.465811 -0.182253
#
# [450 rows x 8 columns]

# %%
# Build the Place Details URL
for place_id in new_df['Place ID']:
    place_details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=reviews&key={api_key}"

    # Send the request and get the response
    response = requests.get(place_details_url)
    details = response.json()

    # Extract the reviews
    reviews = details['result'].get('reviews', [])

    # Process each review
    for review in reviews:
        author_name = review.get('author_name')
        rating = review.get('rating')
        relative_time_description = review.get('relative_time_description')
        timestamp = review.get('time')
        print(f"Author: {author_name}, Rating: {rating}, Time: {relative_time_description}")
# Out:
# Author: Terence j Cleary, Rating: 5, Time: 3 weeks ago
# Author: George Reeves, Rating: 1, Time: a year ago
# Author: Jack J, Rating: 1, Time: a year ago
# Author: Samina Barker, Rating: 5, Time: a year ago
# Author: Holistic Jay, Rating: 5, Time: 2 years ago
# Author: Salim Patel, Rating: 5, Time: 7 months ago
# Author: Michael Yates, Rating: 5, Time: 2 weeks ago
# Author: The Throwback Guy, Rating: 5, Time: 4 months ago
# Author: Jackie Cox, Rating: 1, Time: a month ago
# Author: Abid Ahmed, Rating: 1, Time: in the last week
# Author: Renan Luiz, Rating: 5, Time: 3 weeks ago
# Author: Z Grigaitiene, Rating: 5, Time: 2 months ago
# Author: Adrian Stefan Iancu, Rating: 4, Time: 4 months ago
# Author: S D, Rating: 1, Time: 5 months ago
# Author: hukum chawla, Rating: 1, Time: in the last week
# Author: Leanne Salmon, Rating: 5, Time: 6 months ago

#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import sqlite3

# Establish a database connection
conn = sqlite3.connect('Cafe_Database.db')
cursor = conn.cursor()

# Function to store reviews
def store_review(place_id, review_data):
    """
    place_id: string to retrieve the each cafe's place id
    review_data: dict, reviews and its info for each place id
    """
    # SQL query to insert review data into the 'reviews' table
    query = '''INSERT INTO reviews (place_id, author_name, rating, relative_time_description, review_time)
               VALUES (?, ?, ?, ?, ?)'''
    # Execute the query with the review data
    cursor.execute(query, (place_id, review_data['author_name'], review_data['rating'],
                           review_data['relative_time_description'], review_data['time']))
    # Commit the changes
    conn.commit()

# %%
for place_id in new_df['Place ID']:
    place_details_url = f"https://maps.googleapis.com/maps/api/place/details/json?place_id={place_id}&fields=reviews&key={api_key}"
    for review in reviews:
        # Extract needed review data
        review_data = {
            'author_name': review.get('author_name'),
            'rating': review.get('rating'),
            'relative_time_description': review.get('relative_time_description'),
            'time': review.get('time')
        }
        
        # Store the review_data in database
        database.store_review(place_id, review_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       6 review_data = {
#       7     'author_name': review.get('author_name'),
#       8     'rating': review.get('rating'),
#       9     'relative_time_description': review.get('relative_time_description'),
#      10     'time': review.get('time')
#      11 }
#      13 # Store the review_data in your database
# ---> 14 database.store_review(place_id, review_data)
#
# NameError: name 'database' is not defined

# %% [markdown]
# # Data using top_100.csv

# %%
import pandas as pd

# %%
shop_df = pd.read_csv('top_100.csv')
shop_df = shop_df[shop_df['category']=='Coffee Shop']
shop_df
# Out:
#                     Borough       Lat      Lng            name        lat  \
# 0     Barking and Dagenham   51.57478  0.17441    Costa Coffee  51.576890
# 4     Barking and Dagenham   51.57478  0.17441    Costa Coffee  51.576481
# 15    Barking and Dagenham   51.57478  0.17441       Starbucks  51.576281
# 20    Barking and Dagenham   51.57478  0.17441  Harris + Hoole  51.565614
# 23    Barking and Dagenham   51.57478  0.17441       Starbucks  51.577947
# ...                     ...       ...      ...             ...        ...
# 3067         City of London  51.52050 -0.09743         Rosslyn  51.512574
# 3076         City of London  51.52050 -0.09743   Catalyst Cafe  51.519705
# 3079         City of London  51.52050 -0.09743        The Wren  51.512049
# 3082         City of London  51.52050 -0.09743           Briki  51.526369
# 3098         City of London  51.52050 -0.09743   Origin Coffee  51.526347
#
#            lng     category
# 0     0.179497  Coffee Shop
# 4     0.182448  Coffee Shop
# 15    0.181187  Coffee Shop
# 20    0.191278  Coffee Shop
# 23    0.182874  Coffee Shop
# ...        ...          ...
# 3067 -0.093381  Coffee Shop
# 3076 -0.112052  Coffee Shop
# 3079 -0.096799  Coffee Shop
# 3082 -0.108318  Coffee Shop
# 3098 -0.081204  Coffee Shop
#
# [230 rows x 7 columns]

# %%
# Function to fetch location details using latitude and longitude
def get_shop_details(lat, lng):
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=coffee%2shop&inputtype=textquery&locationbias=circle%3A2000%{lat}%2C{lng}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        location_data = response.json()
        return location_data
    else:
        return None

# %%
url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?fields=formatted_address%2Cname%2Crating%2Copening_hours%2Cgeometry&input=coffee%2shop&inputtype=textquery&locationbias=circle%3A2000%51.576890%2C0.179497&key=AIzaSyBxyO-AntGhj6usDddayBdYSNnFoEs4Bo8"
response = requests.get(url)
response.json()['candidates']
# Out:
# []

# %%
shop_df['location_details'] = shop_df.apply(lambda row: get_location_detail(row['lat'], row['lng']), axis=1)
shop_df
